# %% [markdown]
# # Plotting with Julia using Gadfly and DataFrames

# %% [markdown]
# ## General Workflow

# %% [markdown]
# ### Step 1: Include Packages

# %%
using Gadfly, DataFrames
# Out:
# INFO: Recompiling stale cache file /home/sebastian/.julia/lib/v0.4/Gadfly.ji for module Gadfly.
# INFO: Recompiling stale cache file /home/sebastian/.julia/lib/v0.4/Compose.ji for module Compose.
# WARNING: eval from module Compose to Gadfly:
# Expr(:import, :Patchwork)::Any
#   ** incremental compilation may be broken for this module **

# %% [markdown]
# ### Step 2: Get Data

# %%
using RDatasets
iris = dataset("datasets", "iris") # load the iris dataset
# Out:
# 150x5 DataFrames.DataFrame
# | Row | SepalLength | SepalWidth | PetalLength | PetalWidth | Species     |
# |-----|-------------|------------|-------------|------------|-------------|
# | 1   | 5.1         | 3.5        | 1.4         | 0.2        | "setosa"    |
# | 2   | 4.9         | 3.0        | 1.4         | 0.2        | "setosa"    |
# | 3   | 4.7         | 3.2        | 1.3         | 0.2        | "setosa"    |
# | 4   | 4.6         | 3.1        | 1.5         | 0.2        | "setosa"    |
# | 5   | 5.0         | 3.6        | 1.4         | 0.2        | "setosa"    |
# | 6   | 5.4         | 3.9        | 1.7         | 0.4        | "setosa"    |
# | 7   | 4.6         | 3.4        | 1.4         | 0.3        | "setosa"    |
# | 8   | 5.0         | 3.4        | 1.5         | 0.2        | "setosa"    |
# | 9   | 4.4         | 2.9        | 1.4         | 0.2        | "setosa"    |
# | 10  | 4.9         | 3.1        | 1.5         | 0.1        | "setosa"    |
# ...

# %% [markdown]
# ### Step 3: Plot, plot, plot!

# %%
plot(iris, x=:SepalLength, y=:SepalWidth, color=:Species, Geom.point)
# Out:
# Plot(...)

# %% [markdown]
# ## Getting Data

# %% [markdown]
# ### From RDatasets

# %%
# there are lots of common benchmark-datasets available gathered in R-packages in julia you can use them with the following package
using RDatasets
RDatasets.datasets()
# Out:
# 733x5 DataFrames.DataFrame
# | Row | Package | Dataset        | Title                                  |
# |-----|---------|----------------|----------------------------------------|
# | 1   | "COUNT" | "affairs"      | "affairs"                              |
# | 2   | "COUNT" | "azdrg112"     | "azdrg112"                             |
# | 3   | "COUNT" | "azpro"        | "azpro"                                |
# | 4   | "COUNT" | "badhealth"    | "badhealth"                            |
# | 5   | "COUNT" | "fasttrakg"    | "fasttrakg"                            |
# | 6   | "COUNT" | "lbw"          | "lbw"                                  |
# | 7   | "COUNT" | "lbwgrp"       | "lbwgrp"                               |
# | 8   | "COUNT" | "loomis"       | "loomis"                               |
# | 9   | "COUNT" | "mdvis"        | "mdvis"                                |
# | 10  | "COUNT" | "medpar"       | "medpar"                               |
# ...

# %% [markdown]
# ### From csv

# %%
# you can include data from .csv files with readtable
using DataFrames
pegel = readtable("./data/pegel.csv", separator=';')
# Out:
# 96x2 DataFrames.DataFrame
# | Row | Uhrzeit | Pegel |
# |-----|---------|-------|
# | 1   | "00:15" | 146   |
# | 2   | "00:30" | 146   |
# | 3   | "00:45" | 146   |
# | 4   | "01:00" | 146   |
# | 5   | "01:15" | 146   |
# | 6   | "01:30" | 146   |
# | 7   | "01:45" | 147   |
# | 8   | "02:00" | 146   |
# | 9   | "02:15" | 147   |
# | 10  | "02:30" | 147   |
# | 11  | "02:45" | 147   |
# ⋮
# | 85  | "21:15" | 150   |
# | 86  | "21:30" | 150   |
# | 87  | "21:45" | 150   |
# | 88  | "22:00" | 150   |
# | 89  | "22:15" | 150   |
# | 90  | "22:30" | 150   |
# | 91  | "22:45" | 150   |
# | 92  | "23:00" | 150   |
# | 93  | "23:15" | 150   |
# | 94  | "23:30" | 150   |
# | 95  | "23:45" | 150   |
# | 96  | "24:00" | 150   |

# %% [markdown]
# ### Filtering

# %%
# Eingangsdaten filtern
# mittelung
iris_mean = aggregate(iris, :Species, mean)
# Out:
# 3x5 DataFrames.DataFrame
# | Row | Species      | SepalLength_mean | SepalWidth_mean | PetalLength_mean |
# |-----|--------------|------------------|-----------------|------------------|
# | 1   | "setosa"     | 5.006            | 3.428           | 1.462            |
# | 2   | "versicolor" | 5.936            | 2.77            | 4.26             |
# | 3   | "virginica"  | 6.588            | 2.974           | 5.552            |
#
# | Row | PetalWidth_mean |
# |-----|-----------------|
# | 1   | 0.246           |
# | 2   | 1.326           |
# | 3   | 2.026           |

# %%
# subsets
pegel[ pegel[:Uhrzeit] .> "12:00" ,:]
# Out:
# 48x2 DataFrames.DataFrame
# | Row | Uhrzeit | Pegel |
# |-----|---------|-------|
# | 1   | "12:15" | 149   |
# | 2   | "12:30" | 149   |
# | 3   | "12:45" | 149   |
# | 4   | "13:00" | 149   |
# | 5   | "13:15" | 149   |
# | 6   | "13:30" | 149   |
# | 7   | "13:45" | 149   |
# | 8   | "14:00" | 149   |
# | 9   | "14:15" | 149   |
# | 10  | "14:30" | 149   |
# | 11  | "14:45" | 149   |
# ⋮
# | 37  | "21:15" | 150   |
# | 38  | "21:30" | 150   |
# | 39  | "21:45" | 150   |
# | 40  | "22:00" | 150   |
# | 41  | "22:15" | 150   |
# | 42  | "22:30" | 150   |
# | 43  | "22:45" | 150   |
# | 44  | "23:00" | 150   |
# | 45  | "23:15" | 150   |
# | 46  | "23:30" | 150   |
# | 47  | "23:45" | 150   |
# | 48  | "24:00" | 150   |

# %% [markdown]
# ## Plotting

# %%
plot(pegel, x=:Uhrzeit, y=:Pegel, Geom.line())
# Out:
# Plot(...)

# %% [markdown]
# ## Export Plots
